# %%
#Dependencies
import pandas as pd
import tweepy
from datetime import datetime as dt
from datetime import date
from datetime import timedelta
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
from time import strftime
import math


from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from apikeys import consumer_key, consumer_secret, access_token, access_token_secret




import requests
import json
from apikeys import av_key
import pandas as pd
import os
import csv
import sys

from functools import reduce
from scipy import stats

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = "@realDonaldTrump"


# Variable to hold Tweet Texts, created date, number of retweets, number of likes
tweet_texts = []
created_date =[]
retweets=[]
likes=[]


# Create a loop to iteratively run API requests to bypass weekly tweeter API limit
for x in range(1,160):

    # Get all tweets from Trump home feed (for specified number of pages)
    public_tweets = api.user_timeline(target_user, page=x)

    # Loop through all tweets
    for tweet in public_tweets:
        #Converting text to lower case
        txt = tweet['text'].lower()
        tweet_texts.append(txt)
        created_date.append(tweet["created_at"])
        retweets.append(tweet["retweet_count"])
        likes.append(tweet["favorite_count"])
        
#Created new dictionary to hold above variables
trump_tweets = {
                "Tweet" : tweet_texts,
                "Date" : created_date,
                "Retweets" : retweets,
                "Likes" : likes,
                }

#Converted dictionary to dataframe 
trump_tweets = pd.DataFrame(trump_tweets)
trump_tweets.head(5)

trump_tweets.to_csv("Resource_CSVs/Twitter_RawData.csv", index=False, header=True,encoding='utf-8-sig')
# print(len(trump_tweets))

# %%
# Write to CSV -- to insure code runs if there is no internet connectivity and API can't be called
trump_tweets=pd.read_csv('Resource_CSVs/Twitter_RawData.csv')
type(trump_tweets)
trump_tweets
# Out:
#                                                   Tweet  \
# 0     today, it was my great honor to welcome prime ...
# 1     rt @dhsgov: today, dhs, @cbp, and @icegov will...
# 2     congratulations to andres manuel lopez obrador...
# 3     rt @larryelder: beware! #trumpderangementsyndr...
# 4     a big week, especially with our numerous victo...
# 5     the liberal left, also known as the democrats,...
# 6     i will be interviewed by @mariabartiromo at 10...
# 7     when people come into our country illegally, w...
# 8     i will be interviewed by @mariabartiromo on su...
# 9     either we need to elect more republicans in no...
# 10    i never pushed the republicans in the house to...
# 11    a friend of mine and a man who has truly seen ...
# 12    i will be making my choice for justice of the ...
# 13    just spoke to king salman of saudi arabia and ...
# 14    to the great and brave men and women of ice, d...
# 15    the democrats are making a strong push to abol...
# 16    rt @danscavino: “@govmikehuckabee: trump could...
# 17    rt @realdonaldtrump: six months after our tax ...
# 18    rt @realdonaldtrump: before going any further ...
# 19    rt @ivankatrump: thank you @secpompeo. \nit wa...
# 20    rt @ivankatrump: thank you senator alexander f...
# 21    the new plant being built by foxconn in wiscon...
# 22    rt @foxbusiness: .@ivankatrump: "i think one o...
# 23    rt @scavino45: “@icegov new york operation lea...
# 24    six months after our tax cuts, more than 6 mil...
# 25    before going any further today, i want to addr...
# 26    prior to departing wisconsin, i was briefed on...
# 27    america is open for business! \nhttps://t.co/f...
# 28    today, we broke ground on a plant that will pr...
# 29    i am in milwaukee, wisconsin, for meetings. so...
# ...                                                 ...
# 3145  rt @vp: our president is choosing to put ameri...
# 3146  rt @foxandfriends: wall street hits record hig...
# 3147                          make america great again!
# 3148  my job as president is to do everything within...
# 29    Thu Jun 28 13:06:01 +0000 2018     16550   89896
# ...                              ...       ...     ...
# 3145  Fri Jun 02 10:31:03 +0000 2017      9140       0
# 3146  Fri Jun 02 10:08:24 +0000 2017      9104       0
# 3147  Fri Jun 02 01:00:35 +0000 2017     45862  156773
# 3148  Thu Jun 01 22:50:29 +0000 2017     21372   89229
# 3149  Thu Jun 01 19:03:10 +0000 2017      6777   36828
# 3150  Thu Jun 01 11:05:21 +0000 2017     24169   87998
# 3151  Thu Jun 01 01:05:17 +0000 2017     16462   75873
# 3152  Thu Jun 01 00:40:01 +0000 2017     27583  109098
# 3153  Wed May 31 21:52:54 +0000 2017      7071   41647
# 3154  Wed May 31 20:04:45 +0000 2017     12524   57557
# 3155  Wed May 31 13:08:41 +0000 2017     13193   69333
# 3156  Wed May 31 13:05:14 +0000 2017     11703   62858
# 3157  Wed May 31 11:14:48 +0000 2017     50112  184786
# 3158  Wed May 31 10:45:27 +0000 2017     12341   56468
# 3159  Wed May 31 10:37:42 +0000 2017     13142   53436
# 3160  Wed May 31 10:09:22 +0000 2017     79653  199097
# 3161  Tue May 30 14:01:16 +0000 2017      7165       0
# 3162  Tue May 30 14:00:50 +0000 2017      5964       0
# 3163  Tue May 30 13:59:28 +0000 2017     18759   74031
# 3164  Tue May 30 11:04:48 +0000 2017     20515   82006
# 3165  Tue May 30 10:40:36 +0000 2017     21511   84940
# 3166  Mon May 29 12:36:37 +0000 2017     14212   88150
# 3167  Mon May 29 12:35:34 +0000 2017     34793  145136
# 3168  Mon May 29 12:18:52 +0000 2017     11852   62374
# 3169  Mon May 29 12:11:59 +0000 2017     25373  101667
# 3170  Mon May 29 00:20:11 +0000 2017     27956  110078
# 3171  Mon May 29 00:07:01 +0000 2017     14919   71972
# 3172  Sun May 28 23:57:19 +0000 2017     12855   67152
# 3173  Sun May 28 14:43:53 +0000 2017     15707   66522
# 3174  Sun May 28 12:45:45 +0000 2017     13937   66926
#
# [3175 rows x 4 columns]

# %%
# Created list of key words
# keywords = ['sad','earnings', 'election', 'futures', 'investor', 'low', 'market', 'nasdaq', 'north korea', 'stock',
# 'market', 'correction', 'trading', 'unemployment','wall street','china','ban',
# 'bull', 'kim', 'price', 'high', 'corporate', 'global warming', 'tariff', 'tax cut', 'jobs', 'economy', 'trade', 'missile', 'nuclear', 'jobs', 'wages',
# 'maga']

# %%
keywords=pd.read_csv('Resource_CSVs/keywords.csv')
type(keywords)
# Out:
# pandas.core.frame.DataFrame

# %%
#Filtered tweets based on keywords and defined variables to hold
filtered_tweet_texts = []
filtered_created_date =[]
filtered_retweets=[]
filtered_likes=[]
filtered_id=[]
keys=[]
#Variables to hold sentiment analysis
compound_list = []
pos_list = []
neu_list = []
neg_list = []
# i = 0

# Looping through tweets
for tweet in trump_tweets.iterrows():
    for key in keywords['keywords']:
        #Used regular expression to find specific tweets based on keyword
        if re.search(key,tweet[1]['Tweet']):
            #Not all tweets will have keyword, catching tweets that match
            try:
                filtered_tweet_texts.append(tweet[1]["Tweet"])
                filtered_created_date.append(tweet[1]["Date"])
                filtered_retweets.append(tweet[1]["Retweets"])
                filtered_likes.append(tweet[1]["Likes"])
                keys.append(key)
                # Performed sentiment analysis using Vader
                compound = analyzer.polarity_scores(tweet[1]["Tweet"])["compound"]
                pos = analyzer.polarity_scores(tweet[1]["Tweet"])["pos"]
                neu = analyzer.polarity_scores(tweet[1]["Tweet"])["neu"]
                neg = analyzer.polarity_scores(tweet[1]["Tweet"])["neg"]
                compound_list.append(compound)
                pos_list.append(pos)
                neu_list.append(neu)
                neg_list.append(neg)
#                 i += 1   
            except:
                    print('Missing Data')                      
#Create new dictionary for filtered tweets

filtered_trump_tweets = {
                "Tweet" : filtered_tweet_texts,
                "Date" : filtered_created_date,
                "Retweets" : filtered_retweets,
                "Likes" : filtered_likes,
                "Keyword" : keys,
                "Positive" : pos_list,
                "Negative" : neg_list,
                "Neutral" : neu_list,
                "Compound" : compound_list,
                }               

#Convert dictionary to dataframe
filtered_trump_tweets = pd.DataFrame(filtered_trump_tweets)

#Convert date YYYY/MM/DD format
filtered_trump_tweets["Date"] = pd.to_datetime(filtered_trump_tweets["Date"])
filtered_trump_tweets["Date"] = filtered_trump_tweets["Date"].dt.strftime("%Y-%m-%d")

# filtered_trump_tweets
# Write to CSV
outfile = os.path.join("Resource_CSVs","Filtered_tweets.csv")
filtered_trump_tweets.to_csv(outfile, encoding = "utf-8", index=False, header = True)

# %%
# Grouping by Tweets and concatenating keywords
grouped_keywords = filtered_trump_tweets.groupby(['Tweet'])['Keyword'].apply(list).reset_index()


#merged grouped data frame with filtered data frame
merged_table = pd.merge(grouped_keywords, filtered_trump_tweets, on="Tweet")
# merged_table=merged_table.drop_duplicates(['Tweet'], keep=False, inplace=False)

#Dropped unwanted column
merged_table = merged_table.drop(['Keyword_y'], axis=1)

#Dropped duplicate tweets
merged_table=merged_table.drop_duplicates(['Tweet'], keep='first', inplace=False).reset_index()

#Display
merged_table
# Out:
#      index                                              Tweet  \
# 0        0  "after 14 years, u.s. beef hits chinese market...
# 1        3  "america's labor market continues to boom" job...
# 2        8  "corporations have never made as much money as...
# 3       10  "dow passes 23,000 for the first time, fueled ...
# 4       11  "iran hides behind its assertion of technical ...
# 5       12  "the real big story that affects everybody in ...
# 6       13  ....and has been horrible on virginia economy....
# 7       14  ....and it will get even better with tax cuts!...
# 8       15  ....and japan will put up with this much longe...
# 9       16  ....because he doesn't even live there! he wan...
# 10      17  ....for the middle class. the house and senate...
# 11      18  ....is making. working very hard on tax cuts f...
# 12      21  ....this now allows for the passage of large s...
# 13      22  ....we are finishing our study of tariffs on c...
# 14      23  ....we are getting other countries to reduce a...
# 15      25  ....when i had harley-davidson officials over ...
# 16      26  ...2nd amendment, strong military, isis, histo...
# 17      30  ...and voted against the massive tax cut bill....
# 18      31  ...and west virginia. the fact is the fake new...
# 19      36  ...based on that, the military has hit isis "m...
# 20      37  ...but complain and obstruct. they made only b...
# 21      39  ...congress must immediately pass border legis...
# 25      0.000     0.118    0.882   -0.4215
# 26      0.165     0.189    0.645    0.2481
# 27      0.141     0.101    0.758    0.0258
# 28      0.273     0.000    0.727    0.8360
# 29      0.167     0.000    0.833    0.6369
# ..        ...       ...      ...       ...
# 544     0.206     0.000    0.794    0.7171
# 545     0.000     0.313    0.687   -0.7424
# 546     0.100     0.000    0.900    0.2732
# 547     0.000     0.000    1.000    0.0000
# 548     0.000     0.000    1.000    0.0000
# 549     0.198     0.000    0.802    0.5719
# 550     0.080     0.125    0.795   -0.2960
# 551     0.000     0.081    0.919   -0.2960
# 552     0.000     0.000    1.000    0.0000
# 553     0.000     0.302    0.698   -0.7567
# 554     0.000     0.087    0.913   -0.2732
# 555     0.157     0.000    0.843    0.6249
# 556     0.244     0.087    0.669    0.6124
# 557     0.000     0.237    0.763   -0.6476
# 558     0.201     0.069    0.731    0.5983
# 559     0.288     0.102    0.610    0.8126
# 560     0.221     0.071    0.709    0.6856
# 561     0.293     0.000    0.707    0.7827
# 562     0.000     0.242    0.758   -0.7709
# 563     0.000     0.000    1.000    0.0000
# 564     0.177     0.143    0.680    0.1280
# 565     0.472     0.000    0.528    0.9099
# 566     0.000     0.000    1.000    0.0000
# 567     0.000     0.268    0.732   -0.5106
# 568     0.091     0.000    0.909    0.0258
# 569     0.139     0.166    0.695    0.0813
# 570     0.000     0.095    0.905   -0.2732
# 571     0.000     0.331    0.669   -0.7845
# 572     0.000     0.000    1.000    0.0000
# 573     0.146     0.000    0.854    0.4404
#
# [574 rows x 10 columns]

# %%
# Grouped by date 
grouped_date = merged_table.groupby(['Date']).agg({"Likes": "sum","Retweets": "sum","Compound":"mean",
                                                      "Negative":"mean","Neutral":"mean","Positive":"mean"}).apply(list).reset_index()
grouped_date
# Out:
#            Date   Likes  Retweets  Compound  Negative   Neutral  Positive
# 0    2017-05-29  134346     26771  0.470500  0.084500  0.738000  0.177500
# 1    2017-05-30  158971     40270 -0.455050  0.237000  0.676500  0.086500
# 2    2017-06-02       0      9140  0.273200  0.000000  0.896000  0.104000
# 3    2017-06-03  169545     50192  0.338200  0.139000  0.656000  0.205000
# 4    2017-06-05  215976     49100  0.070000  0.138000  0.689667  0.172000
# 5    2017-06-06  183956     42010 -0.646000  0.276000  0.689500  0.034500
# 6    2017-06-09   87610     20591  0.858800  0.000000  0.656000  0.344000
# 7    2017-06-10  165871     39251  0.000000  0.000000  1.000000  0.000000
# 8    2017-06-11  284100     69724 -0.031267  0.111333  0.782667  0.106333
# 9    2017-06-12   84572     18009 -0.151100  0.157000  0.705000  0.138000
# 10   2017-06-13  191833     40279  0.040267  0.072667  0.819667  0.107667
# 11   2017-06-15  145563     51008 -0.421500  0.130000  0.813000  0.057000
# 12   2017-06-16  106893     23341  0.855600  0.000000  0.691000  0.309000
# 13   2017-06-17   99752     19844  0.884700  0.000000  0.600000  0.400000
# 14   2017-06-18  181250     37067  0.490700  0.136000  0.637500  0.226500
# 15   2017-06-19  172095     44005 -0.229300  0.189667  0.685333  0.125333
# 263  2018-06-26  357123     78051  0.218475  0.058750  0.794750  0.146500
# 264  2018-06-28  186127     38597 -0.263450  0.098000  0.902000  0.000000
# 265  2018-06-29   84142     26844  0.515450  0.077500  0.717500  0.205000
# 266  2018-06-30       0     19358  0.250000  0.143000  0.714000  0.143000
#
# [267 rows x 7 columns]

# %%
grouped_date.describe()
# Out:
#                Likes       Retweets    Compound    Negative     Neutral  \
# count     267.000000     267.000000  267.000000  267.000000  267.000000
# mean   167883.385768   41660.434457    0.162942    0.081713    0.780911
# std    114715.936698   30431.581410    0.390864    0.080805    0.115336
# min         0.000000    7816.000000   -0.838800    0.000000    0.405000
# 25%     91356.000000   20004.000000   -0.098700    0.000000    0.695500
# 50%    141794.000000   34493.000000    0.135433    0.072667    0.781500
# 75%    216554.500000   51684.000000    0.485400    0.131125    0.859500
# max    603820.000000  260164.000000    0.887250    0.359000    1.000000
#
#          Positive
# count  267.000000
# mean     0.137384
# std      0.097669
# min      0.000000
# 25%      0.073500
# 50%      0.125333
# 75%      0.193083
# max      0.424000

# %%
#keeping only extremes of sentiments
# was playing around with the index we will need to figure this out

extreme_dates1 = grouped_date[(grouped_date['Negative'] >0.1)].reset_index()
# extreme_dates.drop(columns=[1])
print(extreme_dates1.head())
# extremes1 = (grouped_date['Compound'] >= 0.5) ~ (grouped_date['Compound'] <= 0.5)
#print(len(extreme_dates1))
# Out:
#    index        Date   Likes  Retweets  Compound  Negative   Neutral  Positive
# 0      1  2017-05-30  158971     40270 -0.455050  0.237000  0.676500  0.086500
# 1      3  2017-06-03  169545     50192  0.338200  0.139000  0.656000  0.205000
# 2      4  2017-06-05  215976     49100  0.070000  0.138000  0.689667  0.172000
# 3      5  2017-06-06  183956     42010 -0.646000  0.276000  0.689500  0.034500
# 4      8  2017-06-11  284100     69724 -0.031267  0.111333  0.782667  0.106333

# %%
base_url = 'https://www.alphavantage.co/query?function='

symbol1 = '^GSPC' 
time_series_url = base_url +'TIME_SERIES_DAILY&symbol='+symbol1+'&outputsize=full&apikey='+ av_key
daily_response_SP500 = requests.get(time_series_url)
response_json_SP500 = daily_response_SP500.json()   

opening_SP500 = []
closing_SP500 = []
date_SP500 = []

for key in response_json_SP500["Time Series (Daily)"]:
    
    opening_SP500.append(response_json_SP500["Time Series (Daily)"][key]["1. open"])
    closing_SP500.append(response_json_SP500["Time Series (Daily)"][key]["4. close"])
    date_SP500.append(key)

SP500_df = pd.DataFrame({
    'Date': date_SP500,
    'S&P500 Open': opening_SP500,
    'S&P500 Close': closing_SP500
})


SP500_df = SP500_df[["Date", "S&P500 Open","S&P500 Close"]]
SP500_df = SP500_df.sort_values('Date', ascending = True)  

print (SP500_df.head())

# ^DJI is Dow Jones 30
symbol2 = '^DJI'
time_series_url = base_url +'TIME_SERIES_DAILY&symbol='+symbol2+'&outputsize=full&apikey='+ av_key
daily_response_DJ = requests.get(time_series_url)
response_json_DJ = daily_response_DJ.json()   

opening_DJ = []
closing_DJ = []
date_DJ = []

for key in response_json_DJ["Time Series (Daily)"]:
    
    opening_DJ.append(response_json_DJ["Time Series (Daily)"][key]["1. open"])
    closing_DJ.append(response_json_DJ["Time Series (Daily)"][key]["4. close"])
    date_DJ.append(key)

DJ_df = pd.DataFrame({
    'Date': date_DJ,
    'DJ Open': opening_DJ,
    'DJ Close': closing_DJ
})


DJ_df = DJ_df[["Date", "DJ Open","DJ Close"]]
DJ_df = DJ_df.sort_values('Date', ascending = True)  

print (DJ_df.head())


# ^IXIC is NASDAQ
symbol3 = '^IXIC'
time_series_url = base_url +'TIME_SERIES_DAILY&symbol='+symbol3+'&outputsize=full&apikey='+ av_key
daily_response_NAS = requests.get(time_series_url)
response_json_NAS = daily_response_NAS.json()   

opening_NAS = []
closing_NAS = []
date_NAS = []

for key in response_json_NAS["Time Series (Daily)"]:
    
    opening_NAS.append(response_json_NAS["Time Series (Daily)"][key]["1. open"])
    closing_NAS.append(response_json_NAS["Time Series (Daily)"][key]["4. close"])
    date_NAS.append(key)

NASDAQ_df = pd.DataFrame({
    'Date': date_NAS,
    'NAS Open': opening_NAS,
    'NAS Close': closing_NAS
})


NASDAQ_df = NASDAQ_df[["Date", "NAS Open","NAS Close"]]
NASDAQ_df = NASDAQ_df.sort_values('Date', ascending = True)  

print (NASDAQ_df.head())
# Out:
#             Date S&P500 Open S&P500 Close
# 4653  2000-01-03   1469.2500    1455.2200
# 4652  2000-01-04   1455.2200    1399.4200
# 4651  2000-01-05   1399.4200    1402.1100
# 4650  2000-01-06   1402.1100    1403.4500
# 4649  2000-01-07   1403.4500    1441.4700
#             Date     DJ Open    DJ Close
# 4653  2000-01-03  11501.8496  11357.5098
# 4652  2000-01-04  11349.7500  10997.9297
# 4651  2000-01-05  10989.3701  11122.6504
# 4650  2000-01-06  11113.3701  11253.2598
# 4649  2000-01-07  11247.0596  11522.5596
#             Date   NAS Open  NAS Close
# 4653  2000-01-03  4186.1899  4131.1499
# 4652  2000-01-04  4020.0000  3901.6899
# 4651  2000-01-05  3854.3501  3877.5400
# 4650  2000-01-06  3834.4399  3727.1299
# 4649  2000-01-07  3711.0901  3882.6201

# %%
# Calculating Sector performance for different sector indices
# 1. Banking
bank_data = os.path.join('raw_data', 'Banking.csv')
bank_df=pd.read_csv(bank_data)
bank_df =  bank_df[["Date", "Open", "Close"]]
bank_df = bank_df.rename(index=str, columns={"Open" : "Bank_Open","Close" : "Bank_Close"})
print (bank_df.head())

# 2. Biotech
biotech_data = os.path.join('raw_data', 'Biotech.csv')
biotech_df=pd.read_csv(biotech_data)
biotech_df =  biotech_df[["Date", "Open", "Close"]]
biotech_df = biotech_df.rename(index=str, columns={"Open" : "Biotech_Open","Close" : "Biotech_Close"})
print(biotech_df.head())


# 3. Healthcare
healthcare_data = os.path.join('raw_data', 'Healthcare.csv')
health_df=pd.read_csv(healthcare_data)
health_df =  health_df[["Date", "Open", "Close"]]
health_df = health_df.rename(index=str, columns={"Open" : "Healthcare_Open","Close" : "Healthcare_Close"})
print(health_df.head())

# 4. Housing
housing_data = os.path.join('raw_data', 'Housing.csv')
housing_df=pd.read_csv(housing_data)
housing_df =  housing_df[["Date", "Open", "Close"]]
housing_df = housing_df.rename(index=str, columns={"Open" : "Housing_Open","Close" : "Housing_Close"})
print(housing_df.head())

# 5. Industrials
industrial_data = os.path.join('raw_data', 'Industrials.csv')
industrial_df=pd.read_csv(industrial_data)
industrial_df =  industrial_df[["Date", "Open", "Close"]]
industrial_df = industrial_df.rename(index=str, columns={"Open" : "Industrial_Open","Close" : "Industrial_Close"})
print(industrial_df.head())

# 6. Insurance
insurance_data = os.path.join('raw_data', 'Insurance.csv')
insurance_df=pd.read_csv(insurance_data)
insurance_df =  insurance_df[["Date", "Open", "Close"]]
insurance_df = insurance_df.rename(index=str, columns={"Open" : "Insurance_Open","Close" : "Insurance_Close"})
print(insurance_df.head())

# 7. Oil & Gas
oil_data = os.path.join('raw_data', 'Oil&Gas.csv')
oil_df=pd.read_csv(oil_data)
oil_df =  oil_df[["Date", "Open", "Close"]]
oil_df = oil_df.rename(index=str, columns={"Open" : "Oil-Gas_Open","Close" : "Oil-Gas_Close"})
print(oil_df.head())

# 8. Semiconductor
semi_data = os.path.join('raw_data', 'Semiconductor.csv')
semi_df=pd.read_csv(semi_data)
semi_df =  semi_df[["Date", "Open", "Close"]]
semi_df = semi_df.rename(index=str, columns={"Open" : "Semiconductor_Open","Close" : "Semiconductor_Close"})
print(semi_df.head())

# 9. Telecom
telecom_data = os.path.join('raw_data', 'Telecom.csv')
telecom_df=pd.read_csv(telecom_data)
telecom_df =  telecom_df[["Date", "Open", "Close"]]
telecom_df = telecom_df.rename(index=str, columns={"Open" : "Telecom_Open","Close" : "Telecom_Close"})
print(telecom_df.head())


#10. Utility
utility_data = os.path.join('raw_data', 'Utility.csv')
utility_df=pd.read_csv(utility_data)
utility_df =  utility_df[["Date", "Open", "Close"]]
utility_df = utility_df.rename(index=str, columns={"Open" : "Utility_Open","Close" : "Utility_Close"})
print(utility_df.head())
# Out:
#          Date    Bank_Open   Bank_Close
# 0  2013-07-01  2221.090088  2249.080078
# 1  2013-07-02  2248.560059  2265.409912
# 2  2013-07-03  2256.489990  2272.570068
# 3  2013-07-05  2294.760010  2327.399902
# 4  2013-07-08  2335.919922  2328.719971
#          Date  Biotech_Open  Biotech_Close
# 0  2013-07-01   1860.430054    1863.699951
# 1  2013-07-02   1862.780029    1865.569946
# 2  2013-07-03   1854.880005    1866.469971
# 3  2013-07-05   1882.619995    1900.589966
# 4  2013-07-08   1909.739990    1893.660034
#          Date  Healthcare_Open  Healthcare_Close
# 0  2013-07-01       441.269989        440.750000
# 1  2013-07-02       440.420013        440.970001
# 2  2013-07-03       438.299988        440.700012
# 3  2013-07-05       444.700012        448.170013
# 4  2013-07-08       450.279999        447.660004
#          Date  Housing_Open  Housing_Close
# 0  2013-07-01    179.690002     179.070007
# 1  2013-07-02    178.970001     177.070007
# 2  2013-07-03    176.580002     178.240005
# 3  2013-07-05    179.000000     174.199997
# 4  2013-07-08    176.039993     172.770004
#          Date  Industrial_Open  Industrial_Close
# 0  2013-07-01      3085.030029       3100.330078
# 1  2013-07-02      3096.830078       3096.939941
# 2  2013-07-03      3082.330078       3104.429932
# 3  2013-07-05      3133.540039       3138.370117
# 4  2013-07-08      3154.320068       3161.520020
#          Date  Insurance_Open  Insurance_Close
# 0  2013-07-01     5741.180176      5820.490234
# 1  2013-07-02     5815.439941      5790.430176
# 2  2013-07-03     5769.629883      5793.290039
# 3  2013-07-05     5856.350098      5882.740234
# 4  2013-07-08     5902.399902      5926.910156
#          Date  Oil-Gas_Open  Oil-Gas_Close
# 0  2013-07-01    253.520004     255.880005
# 1  2013-07-02    255.690002     256.989990
# 2  2013-07-03    256.570007     256.329987
# 3  2013-07-05    257.260010     260.970001
# 4  2013-07-08    262.029999     263.350006
#          Date  Semiconductor_Open  Semiconductor_Close
# 0  2013-07-01          470.019989           467.730011
# 1  2013-07-02          466.880005           468.179993
# 2  2013-07-03          465.750000           469.799988
# 3  2013-07-05          472.279999           476.119995
# 4  2013-07-08          477.470001           466.500000
#          Date  Telecom_Open  Telecom_Close
# 0  2013-07-01    230.220001     229.970001
# 1  2013-07-02    229.330002     229.220001
# 2  2013-07-03    228.550003     230.889999
# 3  2013-07-05    231.660004     231.649994
# 4  2013-07-08    232.610001     231.919998
#          Date  Utility_Open  Utility_Close
# 0  2013-07-01    493.859985     485.890015
# 1  2013-07-02    485.299988     485.839996
# 2  2013-07-03    484.299988     485.359985
# 3  2013-07-05    485.880005     482.869995
# 4  2013-07-08    484.369995     489.160004

# %%
# Merge Index Data Frames
data_frames = [SP500_df, DJ_df, NASDAQ_df, 
               bank_df, biotech_df, health_df,housing_df, industrial_df, 
               insurance_df, oil_df, semi_df, telecom_df, utility_df]

# To keep the values that belong to the same date you need to merge it on the DATE

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Date'],
                                            how='outer'), data_frames)

main_df=df_merged.dropna(axis=0)
main_df.head()
# Out:
#             Date S&P500 Open S&P500 Close     DJ Open    DJ Close   NAS Open  \
# 3393  2013-07-01   1609.7800    1614.9600  14911.5996  14974.9600  3430.4800
# 3394  2013-07-02   1614.2900    1614.0800  14974.9600  14932.4102  3430.6899
# 3395  2013-07-03   1611.4800    1615.4100  14923.7305  14988.3701  3420.2700
# 3396  2013-07-05   1618.6500    1631.8900  14995.4600  15135.8398  3468.4800
# 3397  2013-07-08   1634.2000    1640.4600  15137.2197  15224.6904  3493.8101
#
#       NAS Close    Bank_Open   Bank_Close  Biotech_Open      ...        \
# 3393  3434.4900  2221.090088  2249.080078   1860.430054      ...
# 3394  3433.3999  2248.560059  2265.409912   1862.780029      ...
# 3395  3443.6699  2256.489990  2272.570068   1854.880005      ...
# 3396  3479.3799  2294.760010  2327.399902   1882.619995      ...
# 3397  3484.8301  2335.919922  2328.719971   1909.739990      ...
#
#       Insurance_Open  Insurance_Close  Oil-Gas_Open  Oil-Gas_Close  \
# 3393     5741.180176      5820.490234    253.520004     255.880005
# 3394     5815.439941      5790.430176    255.690002     256.989990
# 3395     5769.629883      5793.290039    256.570007     256.329987
# 3396     5856.350098      5882.740234    257.260010     260.970001
# 3397     5902.399902      5926.910156    262.029999     263.350006
#
#       Semiconductor_Open  Semiconductor_Close  Telecom_Open  Telecom_Close  \
# 3393          470.019989           467.730011    230.220001     229.970001
# 3394          466.880005           468.179993    229.330002     229.220001
# 3395          465.750000           469.799988    228.550003     230.889999
# 3396          472.279999           476.119995    231.660004     231.649994
# 3397          477.470001           466.500000    232.610001     231.919998
#
#       Utility_Open  Utility_Close
# 3393    493.859985     485.890015
# 3394    485.299988     485.839996
# 3395    484.299988     485.359985
# 3396    485.880005     482.869995
# 3397    484.369995     489.160004
#
# [5 rows x 27 columns]

# %%
# Clean this up
# Merge Index Data Frames
# fin_table1 = pd.merge(SP500_df, DJ_df, on= "Date", how = "left")
# main_df = pd.merge(fin_table1, NASDAQ_df, on= "Date", how = "left")
# main_df.head()

# %%
# Write to CSV -- to insure code runs if there is no internet connectivity and API can't be called
outfile = os.path.join("Resource_CSVs","Index_Sector_Raw_data.csv")
main_df.to_csv(outfile, encoding = "utf-8", index=False, header = True)

main_df=pd.read_csv('Resource_CSVs/Index_Sector_Raw_data.csv')
main_df.head()
# Out:
#          Date  S&P500 Open  S&P500 Close     DJ Open    DJ Close   NAS Open  \
# 0  2013-07-01      1609.78       1614.96  14911.5996  14974.9600  3430.4800
# 1  2013-07-02      1614.29       1614.08  14974.9600  14932.4102  3430.6899
# 2  2013-07-03      1611.48       1615.41  14923.7305  14988.3701  3420.2700
# 3  2013-07-05      1618.65       1631.89  14995.4600  15135.8398  3468.4800
# 4  2013-07-08      1634.20       1640.46  15137.2197  15224.6904  3493.8101
#
#    NAS Close    Bank_Open   Bank_Close  Biotech_Open      ...        \
# 0  3434.4900  2221.090088  2249.080078   1860.430054      ...
# 1  3433.3999  2248.560059  2265.409912   1862.780029      ...
# 2  3443.6699  2256.489990  2272.570068   1854.880005      ...
# 3  3479.3799  2294.760010  2327.399902   1882.619995      ...
# 4  3484.8301  2335.919922  2328.719971   1909.739990      ...
#
#    Insurance_Open  Insurance_Close  Oil-Gas_Open  Oil-Gas_Close  \
# 0     5741.180176      5820.490234    253.520004     255.880005
# 1     5815.439941      5790.430176    255.690002     256.989990
# 2     5769.629883      5793.290039    256.570007     256.329987
# 3     5856.350098      5882.740234    257.260010     260.970001
# 4     5902.399902      5926.910156    262.029999     263.350006
#
#    Semiconductor_Open  Semiconductor_Close  Telecom_Open  Telecom_Close  \
# 0          470.019989           467.730011    230.220001     229.970001
# 1          466.880005           468.179993    229.330002     229.220001
# 2          465.750000           469.799988    228.550003     230.889999
# 3          472.279999           476.119995    231.660004     231.649994
# 4          477.470001           466.500000    232.610001     231.919998
#
#    Utility_Open  Utility_Close
# 0    493.859985     485.890015
# 1    485.299988     485.839996
# 2    484.299988     485.359985
# 3    485.880005     482.869995
# 4    484.369995     489.160004
#
# [5 rows x 27 columns]

# %%
# Calculate Returns On Indices
# Calculate Returns for S&P500

SP500_same_day =[]
SP500_one_day = []
SP500_two_day =[]

for row in range(len(main_df)):
   same_day_open= float(main_df["S&P500 Open"][row])
   same_day_close= float(main_df["S&P500 Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   SP500_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["S&P500 Close"][row])
       next_day_close = float(main_df["S&P500 Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       SP500_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       SP500_one_day.append(one_day_change)

   if row + 2 < len(main_df):
       prev_day_close= float(main_df["S&P500 Close"][row])
       
       two_day_close = float(main_df["S&P500 Close"][(row + 2)])
       two_day_change = round(((two_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       SP500_two_day.append(two_day_change)
       
   else:
       two_day_change = 0
       SP500_two_day.append(two_day_change)


# Calculate Returns for Dow Jones

DJ_same_day =[]
DJ_one_day = []
DJ_two_day =[]

for row in range(len(main_df)):
   same_day_open= float(main_df["DJ Open"][row])
   same_day_close= float(main_df["DJ Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   DJ_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["DJ Close"][row])
       next_day_close = float(main_df["DJ Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       DJ_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       DJ_one_day.append(one_day_change)

   if row + 2 < len(main_df):
       prev_day_close= float(main_df["DJ Close"][row])
       
       two_day_close = float(main_df["DJ Close"][(row + 2)])
       two_day_change = round(((two_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       DJ_two_day.append(two_day_change)
       
   else:
       two_day_change = 0
       DJ_two_day.append(two_day_change)
   

# Calculate Returns for Nasdaq

NASDAQ_same_day =[]
NASDAQ_one_day = []
NASDAQ_two_day =[]

for row in range(len(main_df)):
   same_day_open= float(main_df["NAS Open"][row])
   same_day_close= float(main_df["NAS Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   NASDAQ_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["NAS Close"][row])
       next_day_close = float(main_df["NAS Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       NASDAQ_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       NASDAQ_one_day.append(one_day_change)

   if row + 2 < len(main_df):
       prev_day_close= float(main_df["NAS Close"][row])
       
       two_day_close = float(main_df["NAS Close"][(row + 2)])
       two_day_change = round(((two_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       NASDAQ_two_day.append(two_day_change)
       
   else:
       two_day_change = 0
       NASDAQ_two_day.append(two_day_change)

# %%
# Writting sector performance data to main data frame

main_df["S&P500 Same-Day Change"] = SP500_same_day
main_df["S&P500 1-Day Change"] = SP500_one_day
main_df["S&P500 2-Day Change"] = SP500_two_day

main_df["DJ Same-Day Change"] = DJ_same_day
main_df["DJ 1-Day Change"] = DJ_one_day
main_df["DJ 2-Day Change"] = DJ_two_day


main_df["NAS Same-Day Change"] = NASDAQ_same_day
main_df["NAS 1-Day Change"] = NASDAQ_one_day
main_df["NAS 2-Day Change"] = NASDAQ_two_day

main_df.head()
# Out:
#          Date  S&P500 Open  S&P500 Close     DJ Open    DJ Close   NAS Open  \
# 0  2013-07-01      1609.78       1614.96  14911.5996  14974.9600  3430.4800
# 1  2013-07-02      1614.29       1614.08  14974.9600  14932.4102  3430.6899
# 2  2013-07-03      1611.48       1615.41  14923.7305  14988.3701  3420.2700
# 3  2013-07-05      1618.65       1631.89  14995.4600  15135.8398  3468.4800
# 4  2013-07-08      1634.20       1640.46  15137.2197  15224.6904  3493.8101
#
#    NAS Close    Bank_Open   Bank_Close  Biotech_Open        ...         \
# 0  3434.4900  2221.090088  2249.080078   1860.430054        ...
# 1  3433.3999  2248.560059  2265.409912   1862.780029        ...
# 2  3443.6699  2256.489990  2272.570068   1854.880005        ...
# 3  3479.3799  2294.760010  2327.399902   1882.619995        ...
# 4  3484.8301  2335.919922  2328.719971   1909.739990        ...
#
#    Utility_Close  S&P500 Same-Day Change  S&P500 1-Day Change  \
# 0     485.890015                    0.32                -0.05
# 1     485.839996                   -0.01                 0.08
# 2     485.359985                    0.24                 1.02
# 3     482.869995                    0.82                 0.53
# 4     489.160004                    0.38                 0.72
#
#    S&P500 2-Day Change  DJ Same-Day Change  DJ 1-Day Change  DJ 2-Day Change  \
# 0                 0.03                0.42            -0.28             0.09
# 1                 1.10               -0.28             0.37             1.36
# 2                 1.55                0.43             0.98             1.58
# 3                 1.25                0.94             0.59             1.09
# 4                 0.74                0.58             0.50             0.44
#
#    NAS Same-Day Change  NAS 1-Day Change  NAS 2-Day Change
# 0                 0.12             -0.03              0.27
# 1                 0.08              0.30              1.34
# 2                 0.68              1.04              1.20
# 3                 0.31              0.16              0.72
# 4                -0.26              0.56              1.03
#
# [5 rows x 36 columns]

# %%
# Calculate Returns On Sector
# 1. Calculate Returns for Banking Sector

Bank_same_day =[]
Bank_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Bank_Open"][row])
   same_day_close= float(main_df["Bank_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Bank_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Bank_Close"][row])
       next_day_close = float(main_df["Bank_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Bank_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Bank_one_day.append(one_day_change)


# 2. Calculate Returns for Biotechnology Sector 

Biotech_same_day =[]
Biotech_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Biotech_Open"][row])
   same_day_close= float(main_df["Biotech_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Biotech_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Biotech_Close"][row])
       next_day_close = float(main_df["Biotech_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Biotech_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Biotech_one_day.append(one_day_change)


# 3. Calculate Returns for Healthcare Sector

Healthcare_same_day =[]
Healthcare_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Healthcare_Open"][row])
   same_day_close= float(main_df["Healthcare_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Healthcare_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Healthcare_Close"][row])
       next_day_close = float(main_df["Healthcare_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Healthcare_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Healthcare_one_day.append(one_day_change)


# 4. Calculate Returns for Housing Sector

Housing_same_day =[]
Housing_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Housing_Open"][row])
   same_day_close= float(main_df["Housing_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Housing_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Housing_Close"][row])
       next_day_close = float(main_df["Housing_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Housing_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Housing_one_day.append(one_day_change)



# 5. Calculate Returns for Industrials Sector

Industrial_same_day =[]
Industrial_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Industrial_Open"][row])
   same_day_close= float(main_df["Industrial_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Industrial_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Industrial_Close"][row])
       next_day_close = float(main_df["Industrial_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Industrial_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Industrial_one_day.append(one_day_change)

# 6. Calculate Returns for Insurance Sector

Insurance_same_day =[]
Insurance_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Insurance_Open"][row])
   same_day_close= float(main_df["Insurance_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Insurance_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Insurance_Close"][row])
       next_day_close = float(main_df["Insurance_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Insurance_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Insurance_one_day.append(one_day_change)


# 7. Calculate Returns for Oil & Gas Sector

Oil_same_day =[]
Oil_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Oil-Gas_Open"][row])
   same_day_close= float(main_df["Oil-Gas_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Oil_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Oil-Gas_Close"][row])
       next_day_close = float(main_df["Oil-Gas_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Oil_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Oil_one_day.append(one_day_change)


# 8. Calculate Returns for Semiconductor Sector

Semiconductor_same_day =[]
Semiconductor_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Semiconductor_Open"][row])
   same_day_close= float(main_df["Semiconductor_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Semiconductor_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Semiconductor_Close"][row])
       next_day_close = float(main_df["Semiconductor_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Semiconductor_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Semiconductor_one_day.append(one_day_change)

# 9. Calculate Returns for Telecom Sector

Telecom_same_day =[]
Telecom_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Telecom_Open"][row])
   same_day_close= float(main_df["Telecom_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Telecom_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Telecom_Close"][row])
       next_day_close = float(main_df["Telecom_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Telecom_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Telecom_one_day.append(one_day_change)

#10. Calculate Returns for Utility Sector

Utility_same_day =[]
Utility_one_day = []

for row in range(len(main_df)):
   same_day_open= float(main_df["Utility_Open"][row])
   same_day_close= float(main_df["Utility_Close"][row])
   same_day_change = round(((same_day_close - same_day_open)/same_day_open ) * 100 ,2)
   Utility_same_day.append(same_day_change)
   
   if row + 1 < len(main_df):
       prev_day_close= float(main_df["Utility_Close"][row])
       next_day_close = float(main_df["Utility_Close"][(row + 1)])
       one_day_change = round(((next_day_close - prev_day_close)/prev_day_close ) * 100 ,2)
       Utility_one_day.append(one_day_change)
       
   else:
       one_day_change = 0
       Utility_one_day.append(one_day_change)

# %%
# Writting sector performance data to main data frame

# 1. Banking
main_df["Banking Same-Day Change"] = Bank_same_day
main_df["Banking 1-Day Change"] = Bank_one_day

# 2. Biotechnology Sector 
main_df["Biotech Same-Day Change"] = Biotech_same_day
main_df["Biotech 1-Day Change"] = Biotech_one_day

# 3. Healthcare Sector
main_df["Healthcare Same-Day Change"] = Healthcare_same_day
main_df["Healthcare 1-Day Change"] = Healthcare_one_day

# 4. Housing Sector
main_df["Housing Same-Day Change"] = Housing_same_day
main_df["Housing 1-Day Change"] = Housing_one_day

# 5. Industrials Sector
main_df["Industrial Same-Day Change"] = Industrial_same_day
main_df["Industrial 1-Day Change"] = Industrial_one_day

# 6. Insurance Sector
main_df["Insurance Same-Day Change"] = Insurance_same_day
main_df["Insurance 1-Day Change"] = Insurance_one_day

# 7. Oil & Gas Sector
main_df["Oil Same-Day Change"] = Oil_same_day
main_df["Oil 1-Day Change"] = Oil_one_day

# 8. Semiconductor Sector
main_df["Semiconductor Same-Day Change"] = Semiconductor_same_day
main_df["Semiconductor 1-Day Change"] = Semiconductor_one_day

# 9. Telecom Sector
main_df["Telecom Same-Day Change"] = Telecom_same_day
main_df["Telecom 1-Day Change"] = Telecom_one_day

#10. Utility Sector
main_df["Utility Same-Day Change"] = Utility_same_day
main_df["Utility 1-Day Change"] = Utility_one_day


# Write to CSV -- to insure code runs if there is no internet connectivity and API can't be called
outfile = os.path.join("Resource_CSVs","Index_Sector_Performance_data.csv")
main_df.to_csv(outfile, encoding = "utf-8", index=False, header = True)

main_df.head()
# Out:
#          Date  S&P500 Open  S&P500 Close     DJ Open    DJ Close   NAS Open  \
# 0  2013-07-01      1609.78       1614.96  14911.5996  14974.9600  3430.4800
# 1  2013-07-02      1614.29       1614.08  14974.9600  14932.4102  3430.6899
# 2  2013-07-03      1611.48       1615.41  14923.7305  14988.3701  3420.2700
# 3  2013-07-05      1618.65       1631.89  14995.4600  15135.8398  3468.4800
# 4  2013-07-08      1634.20       1640.46  15137.2197  15224.6904  3493.8101
#
#    NAS Close    Bank_Open   Bank_Close  Biotech_Open          ...           \
# 0  3434.4900  2221.090088  2249.080078   1860.430054          ...
# 1  3433.3999  2248.560059  2265.409912   1862.780029          ...
# 2  3443.6699  2256.489990  2272.570068   1854.880005          ...
# 3  3479.3799  2294.760010  2327.399902   1882.619995          ...
# 4  3484.8301  2335.919922  2328.719971   1909.739990          ...
#
#    Insurance Same-Day Change  Insurance 1-Day Change  Oil Same-Day Change  \
# 0                       1.38                   -0.52                 0.93
# 1                      -0.43                    0.05                 0.51
# 2                       0.41                    1.54                -0.09
# 3                       0.45                    0.75                 1.44
# 4                       0.42                    0.72                 0.50
#
#    Oil 1-Day Change  Semiconductor Same-Day Change  \
# 0              0.43                          -0.49
# 1             -0.26                           0.28
# 2              1.81                           0.87
# 3              0.91                           0.81
# 4              1.03                          -2.30
#
#    Semiconductor 1-Day Change  Telecom Same-Day Change  Telecom 1-Day Change  \
# 0                        0.10                    -0.11                 -0.33
# 1                        0.35                    -0.05                  0.73
# 2                        1.35                     1.02                  0.33
# 3                       -2.02                    -0.00                  0.12
# 4                        1.05                    -0.30                  1.12
#
#    Utility Same-Day Change  Utility 1-Day Change
# 0                    -1.61                 -0.01
# 1                     0.11                 -0.10
# 2                     0.22                 -0.51
# 3                    -0.62                  1.30
# 4                     0.99                  0.63
#
# [5 rows x 56 columns]

# %%
# Merging Twitter data frame and Stock market data frame
merge_table = pd.merge(extreme_dates1, main_df, on= "Date", how = "left")
merge_table
# Out:
#     index        Date   Likes  Retweets  Compound  Negative   Neutral  \
# 0       1  2017-05-30  158971     40270 -0.455050  0.237000  0.676500
# 1       3  2017-06-03  169545     50192  0.338200  0.139000  0.656000
# 2       4  2017-06-05  215976     49100  0.070000  0.138000  0.689667
# 3       5  2017-06-06  183956     42010 -0.646000  0.276000  0.689500
# 4       8  2017-06-11  284100     69724 -0.031267  0.111333  0.782667
# 5       9  2017-06-12   84572     18009 -0.151100  0.157000  0.705000
# 6      11  2017-06-15  145563     51008 -0.421500  0.130000  0.813000
# 7      14  2017-06-18  181250     37067  0.490700  0.136000  0.637500
# 8      15  2017-06-19  172095     44005 -0.229300  0.189667  0.685333
# 9      16  2017-06-20  300011     74739 -0.027900  0.157000  0.700750
# 10     20  2017-06-28   51334     12429 -0.400300  0.147000  0.779000
# 11     23  2017-07-02  128784     29866 -0.789100  0.275000  0.725000
# 12     24  2017-07-03  215152     48229  0.587550  0.160000  0.625000
# 13     26  2017-07-05  218774     48065 -0.275550  0.102000  0.853000
# 14     28  2017-07-09  155885     34493  0.227800  0.110000  0.731000
# 15     29  2017-07-11       0     10349 -0.226300  0.155000  0.687000
# 16     38  2017-07-25  253228     60240 -0.051060  0.110400  0.793400
# 17     40  2017-07-29  352568     86466 -0.289775  0.152500  0.794750
# 18     41  2017-07-31  120687     28813 -0.623900  0.341000  0.467000
# 4                         NaN                     NaN                  NaN
# 5                        0.31                    0.37                -0.82
# 6                        0.79                    0.51                -0.94
# 7                         NaN                     NaN                  NaN
# 8                       -0.49                   -0.56                -0.68
# 9                       -0.46                   -0.66                -0.53
# 10                       1.17                   -0.11                 0.57
# 11                        NaN                     NaN                  NaN
# 12                       0.67                   -0.87                 2.69
# 13                      -0.87                   -0.72                -2.66
# 14                        NaN                     NaN                  NaN
# 15                      -0.40                    0.34                 0.97
# 16                       0.25                   -0.71                 0.33
# 17                        NaN                     NaN                  NaN
# 18                      -0.06                    0.49                -0.25
# 19                      -0.14                   -1.23                -1.73
# 20                       0.36                    0.43                -0.75
# 21                        NaN                     NaN                  NaN
# 22                       3.07                    1.11                -1.49
# 23                       0.71                   -0.51                 2.05
# 24                       0.51                    0.11                 0.28
# 25                       0.42                   -0.18                 1.31
# 26                       1.01                    0.24                 1.44
# 27                       0.51                    0.44                 2.13
# 28                       0.41                    1.07                 1.01
# 29                       0.44                   -0.43                -0.60
# ..                        ...                     ...                  ...
# 65                      -1.63                   -2.35                -1.81
# 66                      -2.61                    1.94                -0.74
# 67                       0.27                   -1.88                 2.12
# 68                      -1.61                    0.97                -1.88
# 69                       1.63                    0.20                 0.97
# 70                        NaN                     NaN                  NaN
# 71                        NaN                     NaN                  NaN
# 72                      -0.53                    1.06                -0.84
# 73                       0.45                    0.64                 3.17
# 74                      -0.76                    1.27                 0.62
# 75                      -0.10                    0.36                -0.39
# 76                        NaN                     NaN                  NaN
# 77                        NaN                     NaN                  NaN
# 78                      -0.66                   -0.18                -0.84
# 79                      -0.11                   -1.29                -0.15
# 80                      -1.40                    0.09                -0.01
# 81                       0.25                   -1.86                -0.41
# 82                       1.62                    0.54                 1.65
# 83                       0.01                   -0.74                -1.03
# 84                      -0.16                    1.13                -0.27
# 85                      -0.13                   -0.34                -0.07
# 86                      -0.13                   -2.43                -2.77
# 87                        NaN                     NaN                  NaN
# 88                      -1.59                    1.74                 1.17
# 89                       1.22                   -0.91                 1.85
# 90                       0.30                    0.21                -1.12
# 91                       0.38                    0.92                 1.22
# 92                       1.12                   -0.11                -1.56
# 93                      -0.17                   -0.50                -0.01
# 94                        NaN                     NaN                  NaN
#
#     Oil 1-Day Change  Semiconductor Same-Day Change  \
# 0              -0.26                           0.56
# 1                NaN                            NaN
# 2               0.85                           0.34
# 3              -4.52                           0.68
# 4                NaN                            NaN
# 5               1.86                           0.88
# 6               2.11                           0.87
# 7                NaN                            NaN
# 8              -2.31                           0.74
# 9              -3.41                          -1.33
# 10              1.14                           0.94
# 11               NaN                            NaN
# 12             -3.12                          -1.96
# 13             -2.37                           1.35
# 14               NaN                            NaN
# 15             -0.10                           0.80
# 16             -0.53                           0.24
# 17               NaN                            NaN
# 18             -0.83                          -1.07
# 19             -1.06                          -0.16
# 20              0.64                           1.41
# 21               NaN                            NaN
# 22              1.39                          -1.16
# 23              0.71                           0.43
# 24              0.76                           1.44
# 25             -1.36                          -1.41
# 26              2.72                           0.89
# 27              0.47                          -1.53
# 28              0.80                          -0.86
# 29              0.43                           1.00
# ..               ...                            ...
# 65             -0.16                          -1.23
# 66              0.91                          -3.07
# 67             -2.62                           1.26
# 68              2.24                          -3.02
# 69              3.41                           4.18
# 70               NaN                            NaN
# 71               NaN                            NaN
# 72              5.41                          -0.21
# 73              0.98                           0.67
# 74             -0.46                          -1.89
# 75              0.31                          -1.12
# 76               NaN                            NaN
# 77               NaN                            NaN
# 78              1.45                          -1.82
# 79             -0.47                          -2.04
# 80             -1.30                          -1.24
# 81              0.80                           1.87
# 82              0.53                           3.16
# 83              0.88                          -0.24
# 84             -1.15                          -0.33
# 85             -4.28                           0.37
# 86             -0.24                           0.86
# 87               NaN                            NaN
# 88              2.60                          -0.16
# 89             -2.87                           0.11
# 90              0.66                           0.69
# 91              0.75                           0.07
# 92             -0.52                           0.36
# 93             -0.08                          -0.16
# 94               NaN                            NaN
#
#     Semiconductor 1-Day Change  Telecom Same-Day Change  Telecom 1-Day Change  \
# 0                        -0.00                     0.08                 -0.11
# 1                          NaN                      NaN                   NaN
# 2                         0.35                    -0.45                 -0.52
# 3                         0.74                    -0.24                 -0.29
# 4                          NaN                      NaN                   NaN
# 5                         0.64                    -0.00                  0.79
# 6                        -0.33                     0.73                  0.13
# 7                          NaN                      NaN                   NaN
# 8                        -1.20                     0.58                 -0.62
# 9                         1.17                    -0.53                 -0.28
# 10                       -2.51                     0.76                 -1.86
# 11                         NaN                      NaN                   NaN
# 12                        2.08                    -0.21                 -0.39
# 13                       -0.45                     0.30                 -1.08
# 14                         NaN                      NaN                   NaN
# 15                        1.62                     0.22                  0.29
# 16                        1.16                     0.34                 -0.78
# 17                         NaN                      NaN                   NaN
# 18                        0.55                    -0.62                  0.86
# 19                       -2.58                     0.67                 -2.81
# 20                        0.96                     1.20                  0.62
# 21                         NaN                      NaN                   NaN
# 22                        2.01                    -0.61                  1.55
# 23                        0.48                     0.04                 -0.53
# 24                        1.24                     0.36                  0.41
# 25                       -0.41                    -0.32                  0.00
# 26                       -1.97                     1.21                  0.01
# 27                       -0.05                     0.29                  0.14
# 28                        2.36                    -0.12                 -0.14
# 29                        0.87                     0.17                  0.67
# ..                         ...                      ...                   ...
# 65                       -3.29                    -1.26                 -1.59
# 66                        4.24                    -2.62                  2.87
# 67                       -3.90                     1.43                 -3.34
# 68                        1.96                    -2.51                  0.69
# 69                       -1.04                     2.24                  1.02
# 70                         NaN                      NaN                   NaN
# 71                         NaN                      NaN                   NaN
# 72                        3.20                    -0.15                  3.14
# 73                        1.87                     0.37                  1.43
# 74                        0.23                    -1.23                  0.40
# 75                       -1.33                    -0.71                 -0.20
# 76                         NaN                      NaN                   NaN
# 77                         NaN                      NaN                   NaN
# 78                       -0.12                    -1.12                  0.06
# 79                       -1.09                    -0.24                 -1.49
# 80                        1.73                    -1.32                 -0.04
# 81                       -0.52                     0.80                 -1.43
# 82                        0.91                     2.10                  0.69
# 83                        1.26                    -0.59                 -0.33
# 84                        1.62                    -0.16                  0.82
# 85                        0.88                    -0.27                 -0.42
# 86                       -0.71                    -0.43                 -0.56
# 87                         NaN                      NaN                   NaN
# 88                        0.65                     0.25                  0.01
# 89                       -0.78                    -0.33                 -0.51
# 90                        0.41                     0.06                  0.29
# 91                        0.66                     0.15                  0.69
# 92                       -0.23                    -0.09                  0.48
# 93                        0.61                    -0.19                  1.30
# 94                         NaN                      NaN                   NaN
#
#     Utility Same-Day Change  Utility 1-Day Change
# 0                      0.43                  0.49
# 1                       NaN                   NaN
# 2                     -0.35                 -0.15
# 3                     -0.33                  0.33
# 4                       NaN                   NaN
# 5                     -0.32                  0.15
# 6                      0.64                  0.42
# 7                       NaN                   NaN
# 8                     -0.45                  0.09
# 9                      0.04                 -0.66
# 10                    -1.30                 -0.85
# 11                      NaN                   NaN
# 12                    -0.83                 -0.39
# 13                    -0.48                 -0.05
# 14                      NaN                   NaN
# 15                    -0.19                  0.61
# 16                    -0.53                  0.94
# 17                      NaN                   NaN
# 18                     0.31                  0.38
# 19                     0.41                 -0.75
# 20                    -0.23                 -0.00
# 21                      NaN                   NaN
# 22                     0.53                  0.99
# 23                    -0.45                  0.91
# 24                     0.03                 -1.03
# 25                    -0.98                 -0.04
# 26                    -0.85                  0.87
# 27                     0.84                 -0.17
# 28                    -0.06                 -1.22
# 29                     0.75                 -0.03
# ..                      ...                   ...
# 65                     0.45                 -1.43
# 66                    -1.63                  1.05
# 67                     0.21                 -0.78
# 68                    -1.08                  0.39
# 69                     0.41                  0.81
# 70                      NaN                   NaN
# 71                      NaN                   NaN
# 72                     0.10                 -0.72
# 73                     0.02                 -1.29
# 74                     0.36                  1.39
# 75                    -0.97                  0.07
# 76                      NaN                   NaN
# 77                      NaN                   NaN
# 78                     0.40                 -0.01
# 79                     1.19                 -0.28
# 80                    -0.47                 -0.31
# 81                    -0.25                 -0.11
# 82                     0.35                 -0.53
# 83                     0.14                 -0.45
# 84                    -0.22                  1.06
# 85                     0.79                  0.47
# 86                     0.33                  0.05
# 87                      NaN                   NaN
# 88                     0.32                  0.73
# 89                     1.00                  0.14
# 90                    -1.08                 -0.69
# 91                    -0.70                 -2.04
# 92                    -0.17                 -1.05
# 93                    -0.26                  1.27
# 94                      NaN                   NaN
#
# [95 rows x 63 columns]

# %%
# for index, o1 in enumerate(pd.to_numeric(merge_table["S&P500 Open"])):
#     if math.isnan(o1):
#         date_NA = merge_table["Date"][index]
#         #print (date_NA)
#         date_NA = dt.strptime(date_NA, '%Y-%m-%d').date()
#         print (date_NA)

#         date_NA =date_NA  + timedelta(days=1)
#         print (date_NA)

#         date_NA_df = sp_df.loc[sp_df["Date"]== str(date_NA)]
        
#         s1 = float(date_NA_df["S&P500 Open"])
#         s2 = float(date_NA_df["S&P500 Close"])
#         s3 = float(date_NA_df["S&P500 Same-Day Change"])
#         s4 = float(date_NA_df["S&P500 1-Day Change"])
#         s5 = float(date_NA_df["S&P500 2-Day Change"])
#         merge_table["S&P500 Open"][index] = s1
#         merge_table["S&P500 Close"][index] = s2
#         merge_table["S&P500 Same-Day Change"][index] = s3
#         merge_table["S&P500 1-Day Change"][index] = s4
#         merge_table["S&P500 2-Day Change"][index] = s5

# %%
# count = merge_table['S&P500 Open'].value_counts()
# len(count)
merge_table1=merge_table.dropna(axis=0)
merge_table1.head(20)
# Out:
#     index        Date   Likes  Retweets  Compound  Negative   Neutral  \
# 0       1  2017-05-30  158971     40270  -0.45505  0.237000  0.676500
# 2       4  2017-06-05  215976     49100   0.07000  0.138000  0.689667
# 3       5  2017-06-06  183956     42010  -0.64600  0.276000  0.689500
# 5       9  2017-06-12   84572     18009  -0.15110  0.157000  0.705000
# 6      11  2017-06-15  145563     51008  -0.42150  0.130000  0.813000
# 8      15  2017-06-19  172095     44005  -0.22930  0.189667  0.685333
# 9      16  2017-06-20  300011     74739  -0.02790  0.157000  0.700750
# 10     20  2017-06-28   51334     12429  -0.40030  0.147000  0.779000
# 12     24  2017-07-03  215152     48229   0.58755  0.160000  0.625000
# 13     26  2017-07-05  218774     48065  -0.27555  0.102000  0.853000
# 15     29  2017-07-11       0     10349  -0.22630  0.155000  0.687000
# 16     38  2017-07-25  253228     60240  -0.05106  0.110400  0.793400
# 18     41  2017-07-31  120687     28813  -0.62390  0.341000  0.467000
# 19     55  2017-08-16  180372     54505  -0.16990  0.195333  0.640333
# 20     59  2017-08-30   79936     13359  -0.75670  0.302000  0.698000
# 22     66  2017-09-08   76058     19442  -0.33820  0.102000  0.898000
# 23     67  2017-09-13  167871     35860  -0.16560  0.156500  0.781500
# 24     69  2017-09-15  208262     49075  -0.62880  0.236000  0.662000
# 25     72  2017-09-20  122304     35115  -0.01530  0.144667  0.740333
# 26     73  2017-09-22  124920     39133  -0.21680  0.144000  0.688000
#
#     Positive  S&P500 Open  S&P500 Close          ...           \
# 0   0.086500    2411.6699     2412.9099          ...
# 2   0.172000    2437.8301     2436.1001          ...
# 3   0.034500    2431.9199     2429.3301          ...
# 5   0.138000    2425.8799     2429.3899          ...
# 6   0.057000    2424.1399     2432.4600          ...
# 8   0.125333    2442.5500     2453.4600          ...
# 9   0.142000    2450.6599     2437.0300          ...
# 10  0.074000    2428.7000     2440.6899          ...
# 12  0.215000    2431.3899     2429.0100          ...
# 13  0.045000    2430.7800     2432.5400          ...
# 15  0.159000    2427.3501     2425.5300          ...
# 16  0.096200    2477.8799     2477.1299          ...
# 18  0.192000    2475.9399     2470.3000          ...
# 19  0.164667    2468.6299     2468.1101          ...
# 20  0.000000    2446.0601     2457.5901          ...
# 22  0.000000    2462.2500     2461.4299          ...
# 23  0.061500    2493.8899     2498.3701          ...
# 24  0.102500    2495.6699     2500.2300          ...
# 25  0.115000    2506.8401     2508.2400          ...
# 26  0.168000    2497.2600     2502.2200          ...
#
#     Insurance Same-Day Change  Insurance 1-Day Change  Oil Same-Day Change  \
# 0                       -0.04                    1.00                -1.54
# 2                       -0.72                   -1.23                 1.11
# 3                       -0.89                   -0.12                 1.37
# 5                        0.31                    0.37                -0.82
# 6                        0.79                    0.51                -0.94
# 8                       -0.49                   -0.56                -0.68
# 9                       -0.46                   -0.66                -0.53
# 10                       1.17                   -0.11                 0.57
# 12                       0.67                   -0.87                 2.69
# 13                      -0.87                   -0.72                -2.66
# 15                      -0.40                    0.34                 0.97
# 16                       0.25                   -0.71                 0.33
# 18                      -0.06                    0.49                -0.25
# 19                      -0.14                   -1.23                -1.73
# 20                       0.36                    0.43                -0.75
# 22                       3.07                    1.11                -1.49
# 23                       0.71                   -0.51                 2.05
# 24                       0.51                    0.11                 0.28
# 25                       0.42                   -0.18                 1.31
# 26                       1.01                    0.24                 1.44
#
#     Oil 1-Day Change  Semiconductor Same-Day Change  \
# 0              -0.26                           0.56
# 2               0.85                           0.34
# 3              -4.52                           0.68
# 5               1.86                           0.88
# 6               2.11                           0.87
# 8              -2.31                           0.74
# 9              -3.41                          -1.33
# 10              1.14                           0.94
# 12             -3.12                          -1.96
# 13             -2.37                           1.35
# 15             -0.10                           0.80
# 16             -0.53                           0.24
# 18             -0.83                          -1.07
# 19             -1.06                          -0.16
# 20              0.64                           1.41
# 22              1.39                          -1.16
# 23              0.71                           0.43
# 24              0.76                           1.44
# 25             -1.36                          -1.41
# 26              2.72                           0.89
#
#     Semiconductor 1-Day Change  Telecom Same-Day Change  Telecom 1-Day Change  \
# 0                        -0.00                     0.08                 -0.11
# 2                         0.35                    -0.45                 -0.52
# 3                         0.74                    -0.24                 -0.29
# 5                         0.64                    -0.00                  0.79
# 6                        -0.33                     0.73                  0.13
# 8                        -1.20                     0.58                 -0.62
# 9                         1.17                    -0.53                 -0.28
# 10                       -2.51                     0.76                 -1.86
# 12                        2.08                    -0.21                 -0.39
# 13                       -0.45                     0.30                 -1.08
# 15                        1.62                     0.22                  0.29
# 16                        1.16                     0.34                 -0.78
# 18                        0.55                    -0.62                  0.86
# 19                       -2.58                     0.67                 -2.81
# 20                        0.96                     1.20                  0.62
# 22                        2.01                    -0.61                  1.55
# 23                        0.48                     0.04                 -0.53
# 24                        1.24                     0.36                  0.41
# 25                       -0.41                    -0.32                  0.00
# 26                       -1.97                     1.21                  0.01
#
#     Utility Same-Day Change  Utility 1-Day Change
# 0                      0.43                  0.49
# 2                     -0.35                 -0.15
# 3                     -0.33                  0.33
# 5                     -0.32                  0.15
# 6                      0.64                  0.42
# 8                     -0.45                  0.09
# 9                      0.04                 -0.66
# 10                    -1.30                 -0.85
# 12                    -0.83                 -0.39
# 13                    -0.48                 -0.05
# 15                    -0.19                  0.61
# 16                    -0.53                  0.94
# 18                     0.31                  0.38
# 19                     0.41                 -0.75
# 20                    -0.23                 -0.00
# 22                     0.53                  0.99
# 23                    -0.45                  0.91
# 24                     0.03                 -1.03
# 25                    -0.98                 -0.04
# 26                    -0.85                  0.87
#
# [20 rows x 63 columns]

# %%
# Write to CSV
outfile = os.path.join("Resource_CSVs","Main_data_negative.csv")
merge_table1.to_csv(outfile, encoding = "utf-8", index=False, header = True)
